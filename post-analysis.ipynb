# %%
from abtem.measure import Measurement

# %%
import numpy as np
import glob
import os

# %%
for file in glob.glob('*.hdf5'):
    name,_ = file.split('.')
    measurement = Measurement.read(file)
    measurement.save_as_image(name+'.png')

# %%
# %matplotlib notebook

# %%
hdf5file = 'raw_data/POSCAR_1000K_20nm_Zaxis110.hdf5'
measurement = Measurement.read(hdf5file)

# %%
measurement.show(cmap="inferno")
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<AxesSubplot:xlabel='x [Å]', ylabel='y [Å]'>,
#  <matplotlib.image.AxesImage at 0x2b2888f9f670>)

# %%
path, fn = os.path.split(hdf5file)
bn, ext = os.path.splitext(fn)
image_path = os.path.join(path, bn+".png")

# %%
measurement.save_as_image(image_path)

# %%
from abtem.potentials import PotentialArray

ppf = 'raw_data/POSCAR_1000K_20nm_Zaxis110_potential.hdf5'

pa = PotentialArray.read(ppf)

# %%
pa.project().show(cmap="inferno")
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<AxesSubplot:xlabel='x [Å]', ylabel='y [Å]'>,
#  <matplotlib.image.AxesImage at 0x2b2889172f70>)

# %%
path, fn = os.path.split(ppf)
bn, ext = os.path.splitext(fn)
image_path = os.path.join(path, bn+".png")
image_path
# Out:
# 'raw_data/POSCAR_1000K_20nm_Zaxis110_potential.png'

# %%
pa.project().save_as_image(image_path)

# %% [markdown]
# ![](raw_data/POSCAR_1000K_1_Zaxis110.png)
# ![](raw_data/POSCAR_1000K_1_Zaxis110_potential.png)

# %%
with open("time_cost.dat") as f:
    print(f.read())
# Out:
# raw_data/POSCAR_1000K_1_Zaxis110: 12009.81 [s]

# %%
from ase.visualize import view
from ase.io import read

# %%
atoms = read("raw_data/POSCAR_1000K_20nm_Zaxis110", format="vasp")

# %%
view(atoms, viewer="ngl")

# %%
atoms
# Out:
# Atoms(symbols='Hf5612Ta1884Ti7400Zr7504', pbc=True, cell=[48.3, 48.79036790187178, 195.16147160748713])

# %%
atoms.positions.shape
# Out:
# (22400, 3)

# %% [markdown]
# # Mass data export 10 nm cells

# %%
import glob

# %%
potentials_fp = glob.glob("raw_data/*_10nm_*_potential.hdf5")
sims_fp = glob.glob("raw_data/*_10nm_*0.hdf5")

# %%
potentials_fp
# Out:
# ['raw_data/POSCAR_1200K_3_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_1000K_1_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_720K_2_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_1200K_1_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_1520K_1_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_1000K_3_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_1520K_2_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_720K_1_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_1200K_2_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_720K_2_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_1000K_3_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_1520K_1_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_720K_3_10nm_Zaxis100_potential.hdf5',
#  'raw_data/POSCAR_1000K_2_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_1000K_1_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_1200K_1_10nm_Zaxis110_potential.hdf5',
#  'raw_data/POSCAR_1200K_2_10nm_Zaxis100_potential.hdf5',
# ...

# %%
sims_fp
# Out:
# ['raw_data/POSCAR_1000K_2_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1200K_3_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_720K_1_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1200K_3_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_720K_2_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1200K_1_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1000K_1_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1200K_2_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1520K_1_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1520K_2_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1200K_1_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1520K_3_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1000K_3_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_720K_1_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_720K_3_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1520K_2_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1000K_1_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_1200K_2_10nm_Zaxis100.hdf5',
#  'raw_data/POSCAR_1000K_2_10nm_Zaxis110.hdf5',
#  'raw_data/POSCAR_720K_2_10nm_Zaxis100.hdf5',
# ...

# %%
from abtem.measure import Measurement
import os

for file in sims_fp:
    name,_ = os.path.splitext(file)
    measurement = Measurement.read(file)
    print(f"Exporting {name}.png")
    measurement.save_as_image(name+'.png')
# Out:
# Exporting raw_data/POSCAR_1000K_2_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_1200K_3_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_720K_1_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_1200K_3_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_720K_2_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1200K_1_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1000K_1_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_1200K_2_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1520K_1_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1520K_2_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_1200K_1_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_1520K_3_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1000K_3_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_720K_1_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_720K_3_10nm_Zaxis100.png
# Exporting raw_data/POSCAR_1520K_2_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1000K_1_10nm_Zaxis110.png
# Exporting raw_data/POSCAR_1200K_2_10nm_Zaxis100.png
# ...

# %%
from abtem.potentials import PotentialArray

for file in potentials_fp:
    pa = PotentialArray.read(file)
    name,_ = os.path.splitext(file)
    print(f"Exporting {name}.png")
    pa.project().save_as_image(name+".png")
# Out:
# Exporting raw_data/POSCAR_1200K_3_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_1000K_1_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_720K_2_10nm_Zaxis110_potential.png
# Exporting raw_data/POSCAR_1200K_1_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_1520K_1_10nm_Zaxis110_potential.png
# Exporting raw_data/POSCAR_1000K_3_10nm_Zaxis110_potential.png
# Exporting raw_data/POSCAR_1520K_2_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_720K_1_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_1200K_2_10nm_Zaxis110_potential.png
# Exporting raw_data/POSCAR_720K_2_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_1000K_3_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_1520K_1_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_720K_3_10nm_Zaxis100_potential.png
# Exporting raw_data/POSCAR_1000K_2_10nm_Zaxis110_potential.png
# Exporting raw_data/POSCAR_1000K_1_10nm_Zaxis110_potential.png
# ...
